# %%
import random


for seed in range(0,256):
    myList = list(b'f668cf029d2dc4234394e3f7a8S9f15f626Cc257Ce64}2dcd93323933d2{F1a1cd29db')
    
    
    Order = list(range(len(myList)))
    random.seed(seed)
    random.shuffle(Order)

    originalList = [0]*len(myList)   
    for index,originalIndex in enumerate(Order):
        originalList[originalIndex] = myList[index]    
    
    if "FCSC{" in bytes(originalList).decode():
        print(bytes(originalList).decode())
# Out:
# FCSC{d93d32485aec7dc7622f13cd93b922363911c36d2ffd4f829f4e3264d0ac6952}

# %%
# Out:
# (3, (2147483648, 876403979, 445173717, 1493782529, 1482743573, 973493857, 1259222812, 3136504246, 2843681139, 3828380197, 791066257, 2068709343, 3662191650, 2369793388, 1820559778, 4175442155, 3168138904, 1773006936, 4086945425, 1637280382, 1728869020, 1715099110, 2905747709, 2489990894, 477881975, 2851453362, 461223281, 2751326626, 599450892, 3639013356, 1211705335, 4283435759, 2990525176, 1598792270, 2583883378, 3238315014, 1576137966, 2221608350, 3428217758, 2902867735, 455050909, 2947588449, 3249250819, 4169252141, 104771079, 2587672167, 1089819618, 1351105230, 1777975616, 2966942735, 3158049170, 3687191544, 1295448431, 613901942, 835114222, 2743559409, 2873049263, 2507227970, 2214122660, 2927503019, 128440848, 1787964901, 1186051869, 4071423467, 4086966809, 2739041327, 1951914752, 2480136026, 2406643524, 1588162876, 2457604632, 2717740489, 593025558, 2869246437, 2411910503, 2928797567, 1048703710, 1017127306, 891675471, 3243878058, 3717175925, 1121612929, 1599077315, 3774921307,
# ...
