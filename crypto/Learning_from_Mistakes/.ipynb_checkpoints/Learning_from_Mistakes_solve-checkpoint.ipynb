# %%
import ast
from pwn import *
from Crypto.Random.random import getrandbits
import re

host = '0.0.0.0'
port = '4000'

r = remote(host,port)
n = 64

def get_n_samples(r,n):
    assert n > 0
    command = 's'
    A = []
    B = []
    r.recv()
    i = 0
    while i < n:
        r.sendline(command.encode())
        print("Sample get")
        data = r.recv().decode()
        try:
            sample_a = vector(ZZ,list(map(int, re.search(r'\[(.*?)\]', data).group(1).split(', '))))
            sample_b = Integer(re.search(r'\]\n(\d+)', data).group(1))
            A.append(sample_a)
            B.append(sample_b)
            i+=1
            print(i)
        except:
            pass
        
    return A,B
    
test = get_n_samples(r,n)
print(len(test))

r.close()
# Out:
# [x] Opening connection to 0.0.0.0 on port 4000
# [x] Opening connection to 0.0.0.0 on port 4000: Trying 0.0.0.0
# [+] Opening connection to 0.0.0.0 on port 4000: Done
# Sample get
# 1
# Sample get
# 2
# Sample get
# 3
# Sample get
# 4
# Sample get
# 5
# Sample get
# 6
# Sample get
# 7
# Sample get
# 8
# Sample get
# 9
# Sample get
# 10
# Sample get
# 11
# Sample get
# 12
# Sample get
# 13
# Sample get
# 14
# Sample get
# 15
# Sample get
# 16
# Sample get
# 17
# Sample get
# 18
# Sample get
# 19
# Sample get
# 20
# Sample get
# 21
# Sample get
# 22
# Sample get
# 23
# Sample get
# 24
# Sample get
# 25
# Sample get
# 26
# Sample get
# 27
# Sample get
# 28
# Sample get
# Sample get
# 29
# Sample get
# 30
# Sample get
# 31
# Sample get
# Sample get
# 32
# Sample get
# Sample get
# 33
# Sample get
# Sample get
# 34
# Sample get
# Sample get
# 35
# Sample get
# Sample get
# 36
# Sample get
# Sample get
# 37
# Sample get
# Sample get
# 38
# Sample get
# Sample get
# 39
# Sample get
# Sample get
# 40
# Sample get
# Sample get
# 41
# Sample get
# Sample get
# 42
# Sample get
# Sample get
# 43
# Sample get
# Sample get
# 44
# Sample get
# Sample get
# 45
# Sample get
# Sample get
# 46
# Sample get
# Sample get
# 47
# Sample get
# Sample get
# 48
# Sample get
# Sample get
# 49
# Sample get
# Sample get
# 50
# Sample get
# Sample get
# 51
# Sample get
# Sample get
# 52
# Sample get
# Sample get
# 53
# Sample get
# Sample get
# 54
# Sample get
# Sample get
# 55
# Sample get
# Sample get
# 56
# Sample get
# Sample get
# 57
# Sample get
# Sample get
# 58
# Sample get
# Sample get
# 59
# Sample get
# Sample get
# 60
# Sample get
# Sample get
# 61
# Sample get
# 62
# Sample get
# 63
# Sample get
# 64
# 2
# [*] Closed connection to 0.0.0.0 port 4000

# %%
list_of_samples = []
list_of_b = []
for i in range(n):
    a,b = LWE(s)
    list_of_samples.append(vector(ZZ,a))
    list_of_b.append(Integer(b))

A = Matrix(ZZ,list_of_samples)
B = vector(ZZ,list_of_b)

# %%
M=(identity_matrix(n).augment(A.transpose())).stack(vector([0]*n + list(-B)))  

res = M.LLL()
S = res.row(-1)[:n]

# %%
print(M.str())

print(list(S) == list(s))
# Out:
# [     1      0      0      0     70      8     76    148]
# [     0      1      0      0    199     83    207    195]
# [     0      0      1      0    114    152    207    182]
# [     0      0      0      1     80     13    185     51]
# [     0      0      0      0 -68507 -51882 -94560 -82403]
# True
